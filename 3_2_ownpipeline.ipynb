# %%
# !pip install transformers

# %%
import os

os.environ["HF_TOKEN"] = "Your Hugging Face API token here"

# %%
model_name = "google/gemma-3-1b-it"

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# config.json:   0%|          | 0.00/899 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/662 [00:00<?, ?B/s]

# %%
input_prompt = [
    "The Capital of India is"
]

# %%
tokenized = tokenizer(input_prompt, return_tensors="pt")

# %%
tokenized["input_ids"]
# Out:
# tensor([[    2,   818, 16930,   529,  4673,   563]])

# %%
import torch

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.bfloat16
)
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors:   0%|          | 0.00/2.00G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/340 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]

# %%
gen_result = model.generate(tokenized["input_ids"], max_new_tokens = 25)

# %%
gen_result
# Out:
# tensor([[     2,    818,  16930,    529,   4673,    563,   1799,  18390, 236761,
#             108,    818,   5279,    529,   4673,    563,   1799,  18390, 236761,
#             107,    106]])

# %%
output = tokenizer.batch_decode(gen_result)
output
# Out:
# ['<bos>The Capital of India is New Delhi.\n\nThe capital of India is New Delhi.\n<end_of_turn>']
